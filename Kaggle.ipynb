# %%
from time import perf_counter
import numpy as np
import pandas as pd

# %%
# Reads in Kaggle .csv file of NHL stats and performs initial cleaning
def load_data():
    names = ["game_skater_stats", "game_plays", "game_shifts", "game", "player_info", "team_info"]
    t2 = perf_counter()
    df = {}

    print("load")
    for name in names:
        df[name] = pd.read_csv(f"kaggle_stats/{name}.csv").drop_duplicates(ignore_index=True)
        t1, t2 = t2, perf_counter()
        print(f"{name:>25}: {t2 - t1:.4g} sec, {len(df[name])} rows")
        # return a dict of df
    return df

# %%
# Creates a pandas dataframe from a website table given a dictionary of URLs
def read_url(urls):
    total_dfs = []

    for url in urls.keys():
        if urls[url] == "single":
            df = pd.read_html(url)[0]
            df = clean_spo_df(df)
            total_dfs.append(df)
        if urls[url] == "multi":
            dfs = []
            i = "1"
            df = pd.read_html(url + i)[0]
            while len(df) != 0:
                df = clean_capfr_df(df)
                dfs.append(df)
                df = pd.read_html(url + i)[0]
                i = int(i)
                i += 1
                i = str(i)
            combined_df = pd.DataFrame()
            for df in dfs:
                combined_df = pd.concat([combined_df, df], ignore_index=True)
            total_dfs.append(combined_df)

    return total_dfs

# %%
def clean_spo_df(df):
    df.columns = [
        "Rank",
        "Team",
        "Record",
        "Players Active",
        "Avg Age Team",
        "Total Cap Allocations",
        "Long-Term IR Adjustment",
        "Cap Space All",
        "Active",
        "Injured",
        "Injured  Long-Term",
    ]
    df = df[["Rank", "Team", "Total Cap Allocations", "Cap Space All"]]
    df_trimmed = df.iloc[:-2]
    return df_trimmed


def clean_capfr_df(df):
    df = df[["PLAYER", "TEAM", "POS", "CAP HIT", "SALARY"]]
    # NEW LINES: Splitting "PLAYER" Column into first and last names
    # Splitting the "PLAYER" column based on the first occurrence of a space
    df[["prefix", "firstName", "lastName"]] = df["PLAYER"].str.split(" ", n=2, expand=True)
    # Drop the original "PLAYER" column and the "prefix" column
    df = df.drop(columns=["PLAYER", "prefix"])

    return df

# %%
# Breaks NHL dataframe down into individual seasons
def organize_by_season(seasons, df):
    df_orig = df
    nhl_dfs = []
    for season in seasons:
        df = df_orig.copy()
        df["game"] = df["game"].query(f"season == {season}")
        # filter games to just one season
        # when we call df, we are actually calling the keys in the dict of df and this is why we can now call df[]as opposed to df_game....
        for name in ["game_skater_stats", "game_plays", "game_shifts"]:
            # do an inner merge to reduce the number of rows...keeping only the rows where game and game_id match ....
            df[name] = pd.merge(df[name], df["game"][["game_id"]], on="game_id")
            for key, val in df.items():
                print(f"{key:>25}: {len(val)}")
        # reduce df['game_plays'] df in advance
        cols = ["play_id", "game_id", "team_id_for", "event", "time"]
        events = ["Shot", "Blocked Shot", "Missed Shot", "Goal"]
        # using .loc here as a mask
        df["game_plays"] = df["game_plays"].loc[df["game_plays"]["event"].isin(events)]
        # defining "time" col
        df["game_plays"]["time"] = (
            df["game_plays"]["periodTime"] + (df["game_plays"]["period"] - 1) * 1200
        )
        df["game_plays"] = df["game_plays"][cols]

        print(f"reduced game_plays num rows: {len(df['game_plays'])}")

        # initialize corsi df
        # sort all rows by game_id and on ties defer to player_id... everything with the same game_id will be grouped together
        # NEW LINE: Added "timeonice"
        df_corsi = df["game_skater_stats"].sort_values(["game_id", "player_id"], ignore_index=True)[
            ["game_id", "player_id", "team_id", "timeOnIce"]
        ]

        nhl_dfs.append([season, create_corsi_stats(df_corsi, df)])

    return nhl_dfs

# %%
# Takes a list of pandas dataframes, calculates corsi statistics and adds them to dataframes
def create_corsi_stats(df_corsi, df):
    df_corsi[["CF", "CA", "C"]] = np.nan

    game_id_prev = None
    t1 = perf_counter()
    for i, row in df_corsi.iterrows():
        game_id, player_id, team_id = row.iloc[:3]
        if i % 1000 == 0:
            print(f"{i:>6}/{len(df_corsi)}, {perf_counter() - t1:.2f} s")
        if game_id != game_id_prev:
            shifts_game = df["game_shifts"].query(f"game_id == {game_id}")
            plays_game = df["game_plays"].query(f"game_id == {game_id}")
        shifts_player = shifts_game.query(f"player_id == {player_id}")
        mask = (
            shifts_game["shift_start"].searchsorted(plays_game["time"])
            - shifts_game["shift_end"].searchsorted(plays_game["time"])
        ).astype(bool)
        plays_player = plays_game[mask]
        # mask was it for or against our team. is it for team of the player whose player_id we are looking at
        is_our_team = plays_player["team_id_for"] == team_id
        is_missed_shot = plays_player["event"] == "Missed Shot"
        CF = (is_our_team ^ is_missed_shot).sum()
        # number of rows in the df
        CA = len(plays_player) - CF
        C = CF - CA
        df_corsi.iloc[i, 4:] = [CF, CA, C]
    df_corsi["CF_Percent"] = df_corsi["CF"] / (df_corsi["CF"] + df_corsi["CA"])

    # Merging player_info and team_info
    # NEW LINE
    df_corsi = df_corsi.merge(
        df["player_info"][["player_id", "firstName", "lastName", "primaryPosition"]],
        on="player_id",
        how="left",
    )

    # NEW LINE
    df_corsi = df_corsi.merge(
        df["team_info"][["team_id", "teamName", "abbreviation"]], on="team_id", how="left"
    )

    return df_corsi

# %%
def join_dfs(season_dfs, salary_dfs):
    joined_dfs = []

    if len(season_dfs) == len(salary_dfs):
        for season_df, salary_df in zip(season_dfs, salary_dfs):
            # Merge season_df with salary_df based on firstName and lastName
            merged_df = pd.merge(
                season_df[1],
                salary_df[["firstName", "lastName", "CAP HIT", "SALARY"]],
                on=["firstName", "lastName"],
                how="left",
            )

            # Append the merged dataframe to joined_dfs
            joined_dfs.append([season_df[0], merged_df])

    return joined_dfs

# %%
# Writes csv files for individual NHL seasons from a list of pandas dataframes
def write_csv(dfs):
    for df in dfs:
        df[1].to_csv(f"corsi_vals/Corsi_{df[0]}.csv", index=False)

# %%
# Spotrac URLs for team salary totals
spo_url_15 = "https://www.spotrac.com/nhl/cap/_/year/2015/sort/cap_maximum_space2"
spo_url_16 = "https://www.spotrac.com/nhl/cap/_/year/2016/sort/cap_maximum_space2"
spo_url_17 = "https://www.spotrac.com/nhl/cap/_/year/2017/sort/cap_maximum_space2"

# Cap Friendly URLs for player salary totals
cafr_base_15 = "https://www.capfriendly.com/browse/active/2016?hide=clauses,age,handed,skater-stats,goalie-stats&pg="
cafr_base_16 = "https://www.capfriendly.com/browse/active/2017?hide=clauses,age,handed,skater-stats,goalie-stats&pg="
cafr_base_17 = "https://www.capfriendly.com/browse/active/2018?hide=clauses,age,handed,skater-stats,goalie-stats&pg="

# Loading Kaggle files
df_master = load_data()
seasons = [20152016, 20162017, 20172018]
# Out:
# load
#         game_skater_stats: 0.657 sec, 853404 rows
#                game_plays: 10.34 sec, 4217063 rows
#               game_shifts: 2.438 sec, 9900705 rows
#                      game: 0.04263 sec, 23735 rows
#               player_info: 0.008745 sec, 3925 rows
#                 team_info: 0.0006811 sec, 33 rows

# %%
nhl_dfs = organize_by_season(seasons, df_master)
# Out:
#         game_skater_stats: 47553
#                game_plays: 4217063
#               game_shifts: 9900705
#                      game: 1321
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 47553
#                game_plays: 413156
#               game_shifts: 9900705
#                      game: 1321
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 47553
#                game_plays: 413156
#               game_shifts: 1039022
#                      game: 1321
#               player_info: 3925
#                 team_info: 33
# reduced game_plays num rows: 144387
#      0/47553, 0.00 s
#   1000/47553, 3.48 s
#   2000/47553, 6.87 s
#   3000/47553, 9.89 s
#   4000/47553, 12.99 s
#   5000/47553, 16.06 s
#   6000/47553, 19.15 s
#   7000/47553, 22.71 s
#   8000/47553, 25.65 s
#   9000/47553, 28.70 s
#  10000/47553, 32.17 s
#  11000/47553, 35.44 s
#  12000/47553, 38.84 s
#  13000/47553, 41.94 s
#  14000/47553, 45.11 s
#  15000/47553, 48.41 s
#  16000/47553, 51.53 s
#  17000/47553, 54.90 s
#  18000/47553, 57.98 s
#  19000/47553, 61.75 s
#  20000/47553, 64.98 s
#  21000/47553, 68.09 s
#  22000/47553, 71.19 s
#  23000/47553, 74.45 s
#  24000/47553, 78.00 s
#  25000/47553, 81.69 s
#  26000/47553, 85.38 s
#  27000/47553, 88.83 s
#  28000/47553, 92.38 s
#  29000/47553, 95.30 s
#  30000/47553, 98.39 s
#  31000/47553, 101.56 s
#  32000/47553, 104.70 s
#  33000/47553, 107.69 s
#  34000/47553, 110.92 s
#  35000/47553, 114.05 s
#  36000/47553, 117.24 s
#  37000/47553, 120.92 s
#  38000/47553, 124.55 s
#  39000/47553, 128.07 s
#  40000/47553, 132.00 s
#  41000/47553, 135.32 s
#  42000/47553, 138.65 s
#  43000/47553, 142.19 s
#  44000/47553, 145.38 s
#  45000/47553, 148.49 s
#  46000/47553, 151.48 s
#  47000/47553, 154.37 s
#         game_skater_stats: 47406
#                game_plays: 4217063
#               game_shifts: 9900705
#                      game: 1323
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 47406
#                game_plays: 418130
#               game_shifts: 9900705
#                      game: 1323
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 47406
#                game_plays: 418130
#               game_shifts: 1038248
#                      game: 1323
#               player_info: 3925
#                 team_info: 33
# reduced game_plays num rows: 147700
#      0/47406, 0.00 s
#   1000/47406, 3.12 s
#   2000/47406, 5.96 s
#   3000/47406, 8.89 s
#   4000/47406, 11.68 s
#   5000/47406, 14.75 s
#   6000/47406, 17.62 s
#   7000/47406, 20.51 s
#   8000/47406, 23.53 s
#   9000/47406, 26.43 s
#  10000/47406, 29.55 s
#  11000/47406, 32.38 s
#  12000/47406, 35.37 s
#  13000/47406, 38.36 s
#  14000/47406, 41.35 s
#  15000/47406, 44.62 s
#  16000/47406, 48.31 s
#  17000/47406, 52.09 s
#  18000/47406, 56.07 s
#  19000/47406, 60.02 s
#  20000/47406, 63.83 s
#  21000/47406, 66.90 s
#  22000/47406, 70.59 s
#  23000/47406, 74.48 s
#  24000/47406, 78.61 s
#  25000/47406, 82.01 s
#  26000/47406, 85.65 s
#  27000/47406, 89.44 s
#  28000/47406, 93.27 s
#  29000/47406, 97.43 s
#  30000/47406, 101.81 s
#  31000/47406, 105.90 s
#  32000/47406, 110.15 s
#  33000/47406, 114.33 s
#  34000/47406, 118.52 s
#  35000/47406, 122.43 s
#  36000/47406, 126.35 s
#  37000/47406, 130.45 s
#  38000/47406, 134.43 s
#  39000/47406, 138.34 s
#  40000/47406, 141.66 s
#  41000/47406, 144.93 s
#  42000/47406, 148.82 s
#  43000/47406, 152.75 s
#  44000/47406, 156.76 s
#  45000/47406, 160.67 s
#  46000/47406, 164.59 s
#  47000/47406, 168.74 s
#         game_skater_stats: 48780
#                game_plays: 4217063
#               game_shifts: 9900705
#                      game: 1363
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 48780
#                game_plays: 435851
#               game_shifts: 9900705
#                      game: 1363
#               player_info: 3925
#                 team_info: 33
#         game_skater_stats: 48780
#                game_plays: 435851
#               game_shifts: 1048261
#                      game: 1363
#               player_info: 3925
#                 team_info: 33
# reduced game_plays num rows: 157169
#      0/48780, 0.00 s
#   1000/48780, 4.06 s
#   2000/48780, 8.08 s
#   3000/48780, 12.34 s
#   4000/48780, 16.42 s
#   5000/48780, 20.54 s
#   6000/48780, 24.62 s
#   7000/48780, 28.53 s
#   8000/48780, 32.63 s
#   9000/48780, 36.69 s
#  10000/48780, 40.71 s
#  11000/48780, 44.80 s
#  12000/48780, 48.83 s
#  13000/48780, 52.97 s
#  14000/48780, 56.92 s
#  15000/48780, 60.87 s
#  16000/48780, 64.76 s
#  17000/48780, 68.79 s
#  18000/48780, 72.93 s
#  19000/48780, 77.00 s
#  20000/48780, 81.07 s
#  21000/48780, 85.07 s
#  22000/48780, 89.11 s
#  23000/48780, 93.12 s
#  24000/48780, 97.17 s
#  25000/48780, 101.19 s
#  26000/48780, 105.31 s
#  27000/48780, 109.43 s
#  28000/48780, 113.57 s
#  29000/48780, 117.53 s
#  30000/48780, 121.31 s
#  31000/48780, 125.32 s
#  32000/48780, 129.52 s
#  33000/48780, 133.51 s
#  34000/48780, 137.58 s
#  35000/48780, 141.66 s
#  36000/48780, 145.55 s
#  37000/48780, 149.50 s
#  38000/48780, 153.52 s
#  39000/48780, 157.81 s
#  40000/48780, 162.03 s
#  41000/48780, 166.00 s
#  42000/48780, 169.96 s
#  43000/48780, 173.99 s
#  44000/48780, 178.13 s
#  45000/48780, 182.02 s
#  46000/48780, 186.09 s
#  47000/48780, 189.96 s
#  48000/48780, 193.75 s

# %%
nhl_urls = {
    spo_url_15: "single",
    spo_url_16: "single",
    spo_url_17: "single",
    cafr_base_15: "multi",
    cafr_base_16: "multi",
    cafr_base_17: "multi",
}


team_sals_15, team_sals_16, team_sals_17, player_sals_15, player_sals_16, player_sals_17 = read_url(
    nhl_urls
)

dfs = [
    ["team", "20151016", team_sals_15],
    ["team", "20162017", team_sals_16],
    ["team", "20171018", team_sals_17],
    ["player", "20151016", player_sals_15],
    ["player", "20161017", player_sals_16],
    ["player", "20171018", player_sals_17],
]
# Out:
# printing df before cleaning
#    Rank      Team Record Players Active Avg Age Team Total Cap Allocations  \
# 0   1.0  WPG  WPG      -             27         25.0           $57,038,400
# 1   2.0  CAR  CAR      -             21         25.3           $57,310,738
# 2   3.0  NSH  NSH      -             25         27.0           $61,178,945
# 3   4.0  BUF  BUF      -             23         25.5           $62,019,704
# 4   5.0  COL  COL      -             24         26.5           $62,767,942
#
#   Long-Term IR Adjustment Cap Space All       Active     Injured  \
# 0                       -   $14,361,600  $48,642,298  $2,066,667
# 1                       -   $14,089,262  $38,031,076  $5,500,000
# 2                       -   $10,221,055  $59,358,663           -
# 3                       -    $9,380,296  $50,143,098  $6,100,000
# 4                       -    $8,632,058  $52,563,831  $4,500,000
#
#   Injured  Long-Term
# 0         $4,700,000
# 1                  -
# 2                  -
# 3                  -
# 4                  -
# printing trimmed df
#    Rank      Team Total Cap Allocations Cap Space All
# 0   1.0  WPG  WPG           $57,038,400   $14,361,600
# 1   2.0  CAR  CAR           $57,310,738   $14,089,262
# 2   3.0  NSH  NSH           $61,178,945   $10,221,055
# 3   4.0  BUF  BUF           $62,019,704    $9,380,296
# 4   5.0  COL  COL           $62,767,942    $8,632,058
# printing df before cleaning
#    Rank      Team Record Players Active Avg Age Team Total Cap Allocations  \
# 0   1.0  CAR  CAR      -             21         25.4           $55,070,883
# 1   2.0  NJD  NJD      -             19         26.3           $63,384,193
# 2   3.0  TBL  TBL      -             18         25.9           $64,056,091
# 3   4.0  WPG  WPG      -             25         25.6           $64,113,622
# 4   5.0  FLA  FLA      -             24         28.1           $64,675,437
#
#   Long-Term IR Adjustment Cap Space All       Active     Injured  \
# 0                       -   $17,929,117  $40,439,216  $6,000,000
# 1                       -    $9,615,807  $49,974,139           -
# 2                       -    $8,943,909  $41,345,073  $5,800,000
# 3                       -    $8,886,378  $57,245,375  $5,500,000
# 4                       -    $8,324,563  $61,338,323           -
#
#   Injured  Long-Term
# 0                  -
# 1         $8,877,143
# 2         $8,500,000
# 3                  -
# 4                  -
# printing trimmed df
#    Rank      Team Total Cap Allocations Cap Space All
# 0   1.0  CAR  CAR           $55,070,883   $17,929,117
# 1   2.0  NJD  NJD           $63,384,193    $9,615,807
# 2   3.0  TBL  TBL           $64,056,091    $8,943,909
# 3   4.0  WPG  WPG           $64,113,622    $8,886,378
# 4   5.0  FLA  FLA           $64,675,437    $8,324,563
# printing df before cleaning
#    Rank      Team Record Players Active Avg Age Team Total Cap Allocations  \
# 0   1.0  ARI  ARI      -             23         25.4           $57,472,552
# 1   2.0  CAR  CAR      -             20         26.2           $57,873,988
# 2   3.0  MTL  MTL      -             24         25.6           $61,260,710
# 3   4.0  EDM  EDM      -             23         25.6           $63,310,213
# 4   5.0  NSH  NSH      -             24         27.5           $64,340,995
#
#   Long-Term IR Adjustment Cap Space All       Active     Injured  \
# 0                       -   $17,527,448  $44,164,318  $5,500,000
# 1                       -   $17,126,012  $49,691,104           -
# 2                       -   $13,739,290  $51,382,413  $8,857,143
# 3                       -   $11,689,787  $56,801,891           -
# 4                       -   $10,659,005  $60,606,782           -
#
#   Injured  Long-Term
# 0                  -
# 1                  -
# 2                  -
# 3                  -
# 4                  -
# printing trimmed df
#    Rank      Team Total Cap Allocations Cap Space All
# 0   1.0  ARI  ARI           $57,472,552   $17,527,448
# 1   2.0  CAR  CAR           $57,873,988   $17,126,012
# 2   3.0  MTL  MTL           $61,260,710   $13,739,290
# 3   4.0  EDM  EDM           $63,310,213   $11,689,787
# 4   5.0  NSH  NSH           $64,340,995   $10,659,005
# Creating list of dfs to concatenate
#               PLAYER TEAM POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -   C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET  RW  $10,500,000  $13,800,000
# 2   3. Alex Ovechkin  WSH  LW   $9,538,462  $10,000,000
# 3   4. Evgeni Malkin  PIT   C   $9,500,000   $9,500,000
# 4     5. P.K. Subban    -  RD   $9,000,000   $7,000,000
# printing Player Name
# Testing
# Moving to next page
#               PLAYER TEAM POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -   C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET  RW  $10,500,000  $13,800,000
# 2   3. Alex Ovechkin  WSH  LW   $9,538,462  $10,000,000
# 3   4. Evgeni Malkin  PIT   C   $9,500,000   $9,500,000
# 4     5. P.K. Subban    -  RD   $9,000,000   $7,000,000
# printing Player Name
# Testing
# Moving to next page
#                PLAYER TEAM     POS     CAP HIT      SALARY
# 0      51. Mike Green    -      RD  $6,000,000  $6,000,000
# 1  52. Cory Schneider    -       G  $6,000,000  $6,000,000
# 2     53. Milan Lucic  BOS  LW, RW  $6,000,000  $6,500,000
# 3    54. Jordan Staal  CAR   C, LW  $6,000,000  $6,000,000
# 4   55. Logan Couture  SJS       C  $6,000,000  $6,000,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS     CAP HIT      SALARY
# 0  101. Jay Bouwmeester    -      LD  $5,400,000  $5,600,000
# 1    102. Jarome Iginla    -      RW  $5,333,333  $5,500,000
# 2   103. Roberto Luongo    -       G  $5,333,333  $6,714,000
# 3       104. Shane Doan    -  RW, LW  $5,300,000  $4,550,000
# 4    105. Nathan Horton    -      RW  $5,300,000  $6,000,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS     CAP HIT      SALARY
# 0  151. Francois Beauchemin    -      LD  $4,500,000  $4,500,000
# 1          152. Antti Niemi    -       G  $4,500,000  $4,500,000
# 2      153. Mats Zuccarello  MIN  RW, LW  $4,500,000  $4,500,000
# 3       154. Jaroslav Halák    -       G  $4,500,000  $4,750,000
# 4        155. Brad Marchand  BOS      LW  $4,500,000  $4,500,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM    POS     CAP HIT      SALARY
# 0  201. Niklas Hjalmarsson    -  LD/RD  $4,100,000  $4,200,000
# 1       202. Jake Gardiner    -     LD  $4,050,000  $4,050,000
# 2         203. Marc Savard    -      C  $4,021,428    $575,000
# 3       204. Mark Giordano  TOR     LD  $4,020,000  $4,000,000
# 4        205. Carl Hagelin    -     LW  $4,000,000  $5,000,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM POS     CAP HIT      SALARY
# 0      251. Brad Stuart    -  RD  $3,600,000  $3,600,000
# 1       252. Luca Sbisa    -  LD  $3,600,000  $3,200,000
# 2      253. Luke Schenn  NSH  RD  $3,600,000  $3,350,000
# 3  254. Mikael Backlund  CGY   C  $3,575,000  $3,575,000
# 4     255. Mike Ribeiro    -   C  $3,500,000  $3,500,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM        POS     CAP HIT      SALARY
# 0        301. Boyd Gordon    -          C  $3,000,000  $3,000,000
# 1  302. Mathieu Perreault    -  LW, RW, C  $3,000,000  $3,000,000
# 2   303. Stephane Robidas    -         RD  $3,000,000  $3,000,000
# 3      304. David Legwand    -      C, LW  $3,000,000  $3,500,000
# 4       305. Jamie McGinn    -     LW, RW  $2,950,000  $3,000,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS     CAP HIT      SALARY
# 0  351. Shawn Matthias    -   C, LW  $2,300,000  $2,300,000
# 1    352. James Reimer  DET       G  $2,300,000  $2,000,000
# 2    353. Ben Scrivens    -       G  $2,300,000  $2,300,000
# 3   354. Brandon Tanev  SEA  LW, RW  $2,266,250    $925,000
# 4   355. Daniel Winnik    -       C  $2,250,000  $2,700,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS     CAP HIT      SALARY
# 0    401. Chris Stewart    -  RW, LW  $1,700,000  $1,700,000
# 1       402. Jared Boll    -      RW  $1,700,000  $1,700,000
# 2       403. John Moore    -      LD  $1,666,667  $1,300,000
# 3       404. Mike Weber    -      LD  $1,666,667  $2,000,000
# 4  405. Melker Karlsson    -   RW, C  $1,650,000  $1,450,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS     CAP HIT      SALARY
# 0      451. Mike Brown    -      RW  $1,200,000  $1,250,000
# 1  452. Shawn Thornton    -  LW, RW  $1,200,000  $1,200,000
# 2  453. Chris Thorburn    -  RW, LW  $1,200,000  $1,200,000
# 3      454. Riley Nash  NYR   C, RW  $1,150,000  $1,150,000
# 4   455. Patrick Eaves    -  RW, LW  $1,150,000  $1,150,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM POS   CAP HIT    SALARY
# 0        501. Miles Wood  COL  LW  $925,000  $925,000
# 1    502. Steven Santini  LAK  RD  $925,000  $925,000
# 2         503. Alex Lyon  DET   G  $925,000  $925,000
# 3  504. Charlie Lindgren  WSH   G  $925,000  $925,000
# 4   505. Hudson Fasching  NYI  RW  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS   CAP HIT    SALARY
# 0       551. Scott Mayfield  NYI      RD  $925,000  $925,000
# 1  552. Shayne Gostisbehere  DET   LD/RD  $925,000  $925,000
# 2          553. Jake McCabe  TOR   LD/RD  $925,000  $925,000
# 3           554. Jiri Sekac    -  LW, RW  $925,000  $925,000
# 4         555. Tyler Gaudet    -       C  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT SALARY
# 0       601. Sonny Milano  WSH  LW, RW  $894,167     $0
# 1        602. Kevin Fiala  LAK  RW, LW  $894,167     $0
# 2   603. Nikolay Goldobin    -      LW  $894,167     $0
# 3  604. Michael Dal Colle    -      LW  $894,167     $0
# 4    605. Brendan Perlini    -  RW, LW  $894,167     $0
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM    POS   CAP HIT    SALARY
# 0  651. Mike Santorelli    -  C, RW  $875,000  $875,000
# 1   652. Jamie Oleksiak  SEA  LD/RD  $875,000  $875,000
# 2      653. Taylor Beck    -     LW  $875,000  $875,000
# 3    654. Kirill Petrov    -     RW  $875,000  $875,000
# 4  655. Anders Lindbäck    -      G  $875,000  $875,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS   CAP HIT    SALARY
# 0    701. Stefan Noesen  CAR  LW, RW  $863,333  $832,500
# 1     702. Stuart Percy    -      LD  $863,333  $832,500
# 2      703. Radek Faksa  DAL   C, LW  $863,333  $832,500
# 3  704. Derrick Pouliot  DAL      LD  $863,333  $832,500
# 4   705. Mark Scheifele  WPG       C  $863,333  $832,500
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM    POS   CAP HIT    SALARY
# 0       751. Austin Czarnik  DET  C, RW  $817,500  $792,500
# 1     752. Rasmus Andersson  CGY     RD  $817,500        $0
# 2       753. Jakub Nakladal    -     RD  $817,500  $817,500
# 3       754. Linus Arnesson    -     LD  $817,500  $817,500
# 4  755. Phillip Di Giuseppe  VAN     LW  $817,500  $817,500
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0  801. Joonas Kemppainen    -       C  $792,500  $792,500
# 1      802. Frank Vatrano  ANA  LW, RW  $792,500  $742,500
# 2     803. Justin Hickman    -      RW  $792,500  $742,500
# 3    804. Christian Marti    -      LD  $792,500  $742,500
# 4       805. Andrey Pedan    -      LD  $792,500  $792,500
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM POS   CAP HIT    SALARY
# 0    851. Jordan Subban    -  RD  $755,000  $692,500
# 1      852. Danny Biega    -  RD  $755,000  $805,000
# 2     853. Sam Brittain    -   G  $755,000  $780,000
# 3   854. Chris Driedger  SEA   G  $755,000  $755,000
# 4  855. Anthony Stolarz  FLA   G  $753,333  $792,500
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS   CAP HIT    SALARY
# 0  901. Mattias Janmark  EDM  LW, RW  $733,750  $675,000
# 1      902. Erik Cernak  TBL      RD  $732,500        $0
# 2  903. Alex Lintuniemi    -      RD  $729,167  $692,500
# 3        904. Remi Elie    -      LW  $728,333  $717,500
# 4   905. Spencer Martin  CAR       G  $728,333  $692,500
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM    POS   CAP HIT    SALARY
# 0        951. Brad Boyes    -  RW, C  $700,000  $700,000
# 1     952. Jerry D'Amigo    -     RW  $700,000  $700,000
# 2      953. Shane Prince    -     LW  $700,000  $700,000
# 3      954. Cal O'Reilly    -      C  $700,000  $700,000
# 4  955. Craig Cunningham    -  LW, C  $700,000  $700,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS   CAP HIT    SALARY
# 0    1001. Jerome Leduc    -      RD  $687,500  $687,500
# 1  1002. Steve Michalek    -       G  $687,500  $650,000
# 2     1003. Troy Donnay    -      RD  $686,667  $680,000
# 3    1004. Connor Brown  EDM  RW, LW  $686,667  $717,500
# 4   1005. Steven Hodges    -       C  $685,000  $685,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM    POS   CAP HIT    SALARY
# 0        1051. Tanner Kero    -  C, LW  $667,500  $667,500
# 1    1052. Erik Gustafsson  NYR     LD  $667,500  $667,500
# 2  1053. Connor Hellebuyck  WPG      G  $667,500  $667,500
# 3      1054. Ross Johnston  ANA     LW  $666,667  $620,000
# 4        1055. Daniel Zaar    -     RW  $666,667  $650,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM POS   CAP HIT    SALARY
# 0    1101. Oleg Yevenko    -  LD  $650,000  $650,000
# 1  1102. Stefan Elliott    -  RD  $650,000  $650,000
# 2  1103. Daniel Walcott    -  LW  $650,000  $625,000
# 3    1104. Kevin Poulin    -   G  $650,000  $650,000
# 4  1105. Michael Chaput    -   C  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                       PLAYER TEAM     POS   CAP HIT    SALARY
# 0  1151. Nicolas Deslauriers  PHI  LW, RW  $637,500  $650,000
# 1       1152. Philippe Myers  TBL      RD  $636,667        $0
# 2    1153. Jordan Binnington  STL       G  $636,667  $625,000
# 3     1154. Petteri Lindbohm    -      LD  $636,667  $645,000
# 4       1155. Connor Carrick  SEA      RD  $636,667  $655,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM    POS   CAP HIT    SALARY
# 0   1201. Colin McDonald    -     RW  $625,000  $625,000
# 1  1202. Magnus Hellberg  FLA      G  $625,000  $600,000
# 2     1203. Jaime Sifers    -      D  $625,000  $600,000
# 3      1204. Ryan Carter    -  C, LW  $625,000  $625,000
# 4     1205. Nate Prosser    -     RD  $625,000  $600,000
# printing Player Name
# Testing
# Moving to next page
#                        PLAYER TEAM    POS   CAP HIT    SALARY
# 0        1251. Mikko Vainonen    -     LD  $610,000  $640,000
# 1  1252. Alexander Gudbranson    -     RD  $610,000  $610,000
# 2       1253. Brendan Ranford    -     LW  $610,000  $630,000
# 3        1254. Justin Dowling  NJD  C, LW  $610,000  $630,000
# 4            1255. Troy Vance    -      D  $609,167  $575,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM    POS   CAP HIT    SALARY
# 0   1301. Landon Ferraro    -  C, RW  $600,000  $600,000
# 1      1302. John Ramage    -     RD  $600,000  $600,000
# 2    1303. Philip Varone    -      C  $600,000  $600,000
# 3  1304. Brian McGrattan    -     RW  $600,000  $600,000
# 4     1305. Justin Shugg    -     RW  $600,000  $600,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM    POS   CAP HIT    SALARY
# 0        1351. Derek Ryan  EDM  C, RW  $600,000  $600,000
# 1  1352. Fredrik Claesson    -     LD  $600,000  $600,000
# 2     1353. Tyler Randell    -     RW  $600,000  $600,000
# 3       1354. Tommy Cross    -     LD  $600,000  $600,000
# 4         1355. Brad Hunt  COL  LD/RD  $600,000  $600,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM    POS   CAP HIT    SALARY
# 0  1401. Michael Zalewski    -  LW, C  $575,000  $575,000
# 1        1402. Rich Clune    -     LW  $575,000  $575,000
# 2     1403. Kyle Cumiskey    -     LD  $575,000  $575,000
# 3      1404. Eric Boulton    -     LW  $575,000  $575,000
# 4       1405. Peter Budaj    -      G  $575,000  $575,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM POS   CAP HIT    SALARY
# 0       1451. Mike Moore    -  LD  $575,000  $575,000
# 1     1452. Sean Collins    -   C  $575,000  $575,000
# 2       1453. Aaron Ness    -  LD  $575,000  $575,000
# 3    1454. Carter Camper    -   C  $575,000  $575,000
# 4  1455. Patrick Cannone    -   C  $575,000  $575,000
# printing Player Name
# Testing
# Moving to next page
# Finished creating list of dfs to concatenate
# Creating list of dfs to concatenate
#               PLAYER TEAM POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -   C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET  RW  $10,500,000  $13,800,000
# 2    3. Anze Kopitar  LAK   C  $10,000,000  $14,000,000
# 3   4. Alex Ovechkin  WSH  LW   $9,538,462  $10,000,000
# 4   5. Evgeni Malkin  PIT   C   $9,500,000   $9,500,000
# printing Player Name
# Testing
# Moving to next page
#               PLAYER TEAM POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -   C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET  RW  $10,500,000  $13,800,000
# 2    3. Anze Kopitar  LAK   C  $10,000,000  $14,000,000
# 3   4. Alex Ovechkin  WSH  LW   $9,538,462  $10,000,000
# 4   5. Evgeni Malkin  PIT   C   $9,500,000   $9,500,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM POS     CAP HIT      SALARY
# 0   51. Nathan MacKinnon  COL   C  $6,300,000  $5,000,000
# 1     52. Mark Scheifele  WPG   C  $6,125,000  $5,000,000
# 2      53. Braden Holtby    -   G  $6,100,000  $7,000,000
# 3  54. Henrik Zetterberg    -   C  $6,083,333  $7,500,000
# 4        55. Kyle Okposo  FLA  RW  $6,000,000  $8,000,000
# printing Player Name
# Testing
# Moving to next page
#                PLAYER TEAM    POS     CAP HIT      SALARY
# 0   101. Duncan Keith    -     LD  $5,538,462  $6,000,000
# 1   102. Tyson Barrie  NSH     RD  $5,500,000  $5,000,000
# 2    103. Andrew Ladd    -     LW  $5,500,000  $8,000,000
# 3     104. Nick Leddy  STL     LD  $5,500,000  $4,500,000
# 4  105. Andrej Sekera    -  LD/RD  $5,500,000  $6,500,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS     CAP HIT      SALARY
# 0    151. Sami Vatanen    -   LD/RD  $4,875,000  $5,000,000
# 1  152. Marián Gáborík    -      RW  $4,875,000  $6,075,000
# 2     153. Paul Martin    -      LD  $4,850,000  $5,000,000
# 3     154. Ryane Clowe    -  LW, RW  $4,850,000  $4,850,000
# 4    155. Justin Faulk  STL      RD  $4,833,333  $5,500,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS     CAP HIT      SALARY
# 0  201. Marc-Édouard Vlasic  SJS   LD/RD  $4,250,000  $4,250,000
# 1    202. Kevin Shattenkirk  BOS      RD  $4,250,000  $5,200,000
# 2     203. Patric Hörnqvist    -      RW  $4,250,000  $4,750,000
# 3   204. James van Riemsdyk  BOS  LW, RW  $4,250,000  $5,000,000
# 4          205. Tyler Bozak    -   C, RW  $4,200,000  $4,500,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM        POS     CAP HIT      SALARY
# 0  251. Rickard Rakell  PIT     RW, LW  $3,853,672  $3,800,000
# 1   252. Connor Murphy  CHI         RD  $3,850,000  $2,400,000
# 2     253. Darren Helm    -  C, LW, RW  $3,850,000  $5,000,000
# 3      254. Cody Eakin    -          C  $3,850,000  $3,850,000
# 4    255. Chris Kunitz    -     RW, LW  $3,850,000  $3,550,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM    POS     CAP HIT      SALARY
# 0   301. Clayton Stoner    -     LD  $3,250,000  $3,250,000
# 1  302. Zbynek Michalek    -     RD  $3,200,000  $3,200,000
# 2    303. Charlie Coyle  BOS  C, RW  $3,200,000  $2,600,000
# 3      304. Matt Stajan    -      C  $3,125,000  $3,000,000
# 4     305. Kris Russell    -  LD/RD  $3,100,000  $3,100,000
# printing Player Name
# Testing
# Moving to next page
#                PLAYER TEAM     POS     CAP HIT      SALARY
# 0   351. Nail Yakupov    -  RW, LW  $2,500,000  $2,500,000
# 1     352. Ryan Ellis  PHI      RD  $2,500,000  $2,500,000
# 2  353. Jannik Hansen    -      RW  $2,500,000  $3,000,000
# 3  354. Brian Elliott    -       G  $2,500,000  $2,700,000
# 4  355. Tommy Wingels    -  RW, LW  $2,475,000  $2,600,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS     CAP HIT      SALARY
# 0     401. Chad Johnson    -       G  $1,700,000  $1,700,000
# 1   402. Brayden McNabb  VGK      LD  $1,700,000  $1,600,000
# 2       403. John Moore    -      LD  $1,666,667  $1,750,000
# 3  404. Michael Grabner    -  LW, RW  $1,650,000  $1,650,000
# 4  405. Melker Karlsson    -   RW, C  $1,650,000  $1,850,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM     POS     CAP HIT      SALARY
# 0      451. Chris Thorburn    -  RW, LW  $1,200,000  $1,200,000
# 1          452. Paul Byron    -  LW, RW  $1,166,667  $1,300,000
# 2   453. Zemgus Girgensons  BUF   LW, C  $1,150,000  $1,150,000
# 3       454. Chris Stewart    -  RW, LW  $1,150,000  $1,200,000
# 4  455. Michael Hutchinson  DET       G  $1,150,000  $1,000,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM    POS   CAP HIT      SALARY
# 0    501. Jordan Nolan    -     LW  $950,000  $1,000,000
# 1     502. Colin White  MTL  C, RW  $925,000    $925,000
# 2      503. C.J. Smith    -     LW  $925,000    $925,000
# 3  504. Griffen Molino    -      C  $925,000    $925,000
# 4   505. Michael Kapla    -      D  $925,000    $925,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM    POS   CAP HIT    SALARY
# 0  551. Mantas Armalis    -      G  $925,000  $925,000
# 1     552. Kyle Connor  WPG     LW  $925,000  $925,000
# 2       553. Kevin Roy    -  C, LW  $925,000  $925,000
# 3      554. Miles Wood  COL     LW  $925,000  $925,000
# 4  555. Steven Santini  LAK     RD  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                           PLAYER TEAM     POS   CAP HIT    SALARY
# 0            601. Jamie Oleksiak  SEA   LD/RD  $918,750  $918,750
# 1            602. Charlie McAvoy  BOS      RD  $916,667  $900,000
# 2  603. Jakob Forsbacka Karlsson  BOS   RW, C  $916,667  $900,000
# 3                604. Tyson Jost  BUF       C  $916,667        $0
# 4            605. Clayton Keller  UTA  LW, RW  $916,667        $0
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0      651. Mirco Mueller    -      LD  $894,167  $832,500
# 1  652. Henrik Samuelsson    -       C  $894,167  $832,500
# 2     653. Nikita Zadorov  VAN   LD/RD  $894,167  $832,500
# 3   654. André Burakovsky  SEA  RW, LW  $894,167  $832,500
# 4   655. Teuvo Teräväinen  CAR  LW, RW  $894,167  $832,500
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM    POS   CAP HIT    SALARY
# 0  701. Anthony Deangelo  CAR     RD  $863,333  $925,000
# 1      702. Ryan Hartman  MIN  C, RW  $863,333  $832,500
# 2   703. Kasperi Kapanen  STL     RW  $863,333  $925,000
# 3    704. Joshua Ho-Sang    -  RW, C  $863,333  $925,000
# 4    705. Malcolm Subban  CBJ      G  $863,333  $832,500
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM        POS   CAP HIT    SALARY
# 0   751. Teemu Pulkkinen    -         LW  $812,500  $812,500
# 1   752. Cédric Paquette    -  C, LW, RW  $812,500  $800,000
# 2      753. Nate Schmidt  WPG      LD/RD  $812,500  $875,000
# 3    754. Artemi Panarin  NYR         LW  $812,500  $925,000
# 4  755. Alex Nedeljkovic  PIT          G  $811,667  $792,500
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS   CAP HIT    SALARY
# 0     801. Mario Lucia    -      LW  $792,500  $767,500
# 1  802. Jordan Maletta    -       C  $792,500  $692,500
# 2   803. Jere Sallinen    -      LW  $792,500  $792,500
# 3    804. Noel Acciari  PIT   C, RW  $792,500  $892,500
# 4   805. Frank Vatrano  ANA  LW, RW  $792,500  $792,500
# printing Player Name
# Testing
# Moving to next page
#                        PLAYER TEAM        POS   CAP HIT    SALARY
# 0            851. Keegan Lowe    -         LD  $750,000  $750,000
# 1          852. Jordin Tootoo    -         RW  $750,000  $750,000
# 2           853. Ryan Dzingel    -  LW, RW, C  $750,000  $750,000
# 3          854. Klas Dahlbeck    -         LD  $750,000  $750,000
# 4  855. Jonathan Marchessault  VGK     RW, LW  $750,000  $750,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0         901. Vince Dunn  SEA   LD/RD  $728,333        $0
# 1          902. Remi Elie    -      LW  $728,333  $767,500
# 2     903. Spencer Martin  CAR       G  $728,333  $742,500
# 3  904. Daniel Altshuller    -       G  $728,333  $725,000
# 4       905. Givani Smith  SJS  LW, RW  $725,833        $0
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM     POS   CAP HIT    SALARY
# 0         951. Eric Cornel    -       C  $717,500  $667,500
# 1      952. Michael Amadio  VGK  RW, LW  $717,500  $667,500
# 2     953. Alex Schoenborn    -       C  $717,500  $667,500
# 3        954. Kevin Labanc  SJS  RW, LW  $717,500  $667,500
# 4  955. Markus Hännikäinen    -      LW  $717,500  $742,500
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0    1001. Landon Ferraro    -   C, RW  $700,000  $700,000
# 1  1002. Fredrik Claesson    -      LD  $700,000  $700,000
# 2        1003. Linden Vey    -   RW, C  $700,000  $700,000
# 3       1004. Luke Gazdic    -      LW  $700,000  $700,000
# 4   1005. Magnus Pääjärvi    -  LW, RW  $700,000  $700,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS   CAP HIT    SALARY
# 0      1051. Lucas Wallmark    -       C  $683,333  $675,000
# 1          1052. Ben Betker    -      LD  $683,333  $675,000
# 2       1053. Sergei Boikov    -      LD  $681,667  $635,000
# 3  1054. Nicolas Aubé-Kubel  WSH      RW  $680,833  $667,500
# 4       1055. Conor Garland  VAN  RW, LW  $680,556  $660,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM     POS   CAP HIT    SALARY
# 0       1101. Kevin Gravel  NSH      LD  $667,500  $667,500
# 1       1102. Conor Sheary  TBL  LW, RW  $667,500  $667,500
# 2        1103. Tanner Kero    -   C, LW  $667,500  $667,500
# 3    1104. Erik Gustafsson  NYR      LD  $667,500  $667,500
# 4  1105. Connor Hellebuyck  WPG       G  $667,500  $692,500
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM        POS   CAP HIT    SALARY
# 0   1151. Dylan DeMelo  WPG         RD  $650,000  $600,000
# 1    1152. Jordan Weal    -  C, RW, LW  $650,000  $650,000
# 2  1153. Derek Forbort  BOS         LD  $650,000  $650,000
# 3    1154. Taylor Beck    -         LW  $650,000  $650,000
# 4    1155. Derek Grant    -      LW, C  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0  1201. Eetu Laurikainen    -       G  $640,000  $652,500
# 1      1202. Justin Hache    -      LD  $640,000  $665,000
# 2        1203. Martin Frk    -      RW  $639,167  $650,000
# 3       1204. Matt Lorito    -  LW, RW  $637,500  $625,000
# 4      1205. Chris Wagner  COL   RW, C  $637,500  $625,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM     POS   CAP HIT    SALARY
# 0      1251. Corey Tropp    -  RW, LW  $625,000  $600,000
# 1         1252. Mark Alt    -      RD  $625,000  $625,000
# 2  1253. Brendan Ranford    -      LW  $625,000  $625,000
# 3   1254. Justin Dowling  NJD   C, LW  $625,000  $625,000
# 4    1255. Seth Griffith    -   RW, C  $625,000  $625,000
# printing Player Name
# Testing
# Moving to next page
#                        PLAYER TEAM     POS   CAP HIT    SALARY
# 0      1301. Jordan Martinook  CAR  LW, RW  $612,500  $625,000
# 1        1302. Stefan Matteau    -      LW  $612,500  $650,000
# 2        1303. Steven Kampfer  UTA      RD  $612,500  $625,000
# 3         1304. Henri Kiviaho    -       G  $611,666  $615,000
# 4  1305. Alexander Gudbranson    -      RD  $610,000  $635,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM POS   CAP HIT    SALARY
# 0       1351. Garret Ross    -  LW  $600,000  $600,000
# 1  1352. Michael Paliotta    -  RD  $600,000  $600,000
# 2      1353. Brian Strait    -  LD  $600,000  $600,000
# 3  1354. Dustin Stevenson    -  LD  $600,000  $600,000
# 4     1355. Justin Peters    -   G  $600,000  $600,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM    POS   CAP HIT    SALARY
# 0     1401. Stephen Gionta    -  C, RW  $575,000  $575,000
# 1         1402. Adam Pardy    -     LD  $575,000  $575,000
# 2    1403. Devin Setoguchi    -     RW  $575,000  $575,000
# 3  1404. Nicklas Grossmann    -     LD  $575,000  $575,000
# 4       1405. Danny Kristo    -     RW  $575,000  $575,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM POS   CAP HIT    SALARY
# 0        1451. Tom Sestito    -  LW  $575,000  $575,000
# 1  1452. Brandon Mashinter    -  LW  $575,000  $575,000
# 2       1453. Jordan Caron    -  RW  $575,000  $575,000
# 3      1454. Matt Taormina    -  LD  $575,000  $575,000
# 4         1455. Tye McGinn    -  LW  $575,000  $575,000
# printing Player Name
# Testing
# Moving to next page
# Finished creating list of dfs to concatenate
# Creating list of dfs to concatenate
#               PLAYER TEAM    POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -      C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET     RW  $10,500,000  $13,800,000
# 2    3. Anze Kopitar  LAK      C  $10,000,000  $13,000,000
# 3   4. Alex Ovechkin  WSH     LW   $9,538,462  $10,000,000
# 4      5. Jamie Benn  DAL  LW, C   $9,500,000  $13,000,000
# printing Player Name
# Testing
# Moving to next page
#               PLAYER TEAM    POS      CAP HIT       SALARY
# 0  1. Jonathan Toews    -      C  $10,500,000  $13,800,000
# 1    2. Patrick Kane  DET     RW  $10,500,000  $13,800,000
# 2    3. Anze Kopitar  LAK      C  $10,000,000  $13,000,000
# 3   4. Alex Ovechkin  WSH     LW   $9,538,462  $10,000,000
# 4      5. Jamie Benn  DAL  LW, C   $9,500,000  $13,000,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM        POS     CAP HIT      SALARY
# 0      51. Derek Stepan    -      C, RW  $6,500,000  $7,000,000
# 1       52. Carey Price  MTL          G  $6,500,000  $7,000,000
# 2  53. Alex Pietrangelo  VGK         RD  $6,500,000  $7,000,000
# 3     54. Erik Karlsson  PIT         RD  $6,500,000  $7,000,000
# 4      55. Sean Monahan  WPG  C, LW, RW  $6,375,000  $6,500,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM     POS     CAP HIT      SALARY
# 0      101. Jeff Skinner  BUF  LW, RW  $5,725,000  $6,000,000
# 1        102. Marc Staal  PHI      LD  $5,700,000  $6,000,000
# 2        103. Mike Smith    -       G  $5,666,667  $6,000,000
# 3  104. Jason Pominville    -      RW  $5,600,000  $5,000,000
# 4     105. Blake Wheeler  NYR      RW  $5,600,000  $5,800,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM    POS     CAP HIT      SALARY
# 0  151. Frederik Andersen  CAR      G  $5,000,000  $5,000,000
# 1      152. Morgan Rielly  TOR     LD  $5,000,000  $5,000,000
# 2  153. Mikhail Grabovski    -  C, RW  $5,000,000  $6,000,000
# 3        154. Andy Greene    -  LD/RD  $5,000,000  $5,000,000
# 4       155. Matt Moulson    -     LW  $5,000,000  $5,000,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM        POS     CAP HIT      SALARY
# 0  201. Christopher Tanev  DAL         RD  $4,450,000  $5,000,000
# 1     202. Brandon Sutter    -      RW, C  $4,375,000  $4,250,000
# 2       203. Jack Johnson  COL         LD  $4,357,143  $5,000,000
# 3      204. Brendan Smith  NJD  LD/RD, LW  $4,350,000  $5,000,000
# 4         205. Jake Allen  NJD          G  $4,350,000  $3,850,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS     CAP HIT      SALARY
# 0      251. Cam Fowler  ANA   LD/RD  $4,000,000  $4,000,000
# 1  252. Wayne Simmonds    -  RW, LW  $3,975,000  $4,750,000
# 2    253. John Carlson  WSH      RD  $3,966,667  $4,000,000
# 3   254. Johan Franzen    -  RW, LW  $3,954,545  $2,000,000
# 4    255. Colin Wilson    -   C, LW  $3,937,500  $4,000,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS     CAP HIT      SALARY
# 0  301. Clayton Stoner    -      LD  $3,250,000  $3,250,000
# 1   302. Charlie Coyle  BOS   C, RW  $3,200,000  $3,500,000
# 2    303. Trevor Daley    -      RD  $3,166,666  $4,000,000
# 3      304. Sam Gagner  EDM   RW, C  $3,150,000  $2,750,000
# 4   305. Patrick Eaves    -  RW, LW  $3,150,000  $3,300,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM    POS     CAP HIT      SALARY
# 0     351. Kevan Miller    -     RD  $2,500,000  $2,500,000
# 1     352. Brock Nelson  NYI  C, LW  $2,500,000  $3,500,000
# 2       353. Ryan Ellis  PHI     RD  $2,500,000  $3,000,000
# 3    354. Jannik Hansen    -     RW  $2,500,000  $3,000,000
# 4  355. Nathan Beaulieu    -  LD/RD  $2,400,000  $2,300,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM        POS     CAP HIT      SALARY
# 0     401. Mark Letestu    -      C, RW  $1,800,000  $1,800,000
# 1  402. Micheal Ferland    -     LW, RW  $1,750,000  $1,700,000
# 2    403. Brett Ritchie    -         RW  $1,750,000  $1,700,000
# 3      404. Jordan Weal    -  C, RW, LW  $1,750,000  $1,750,000
# 4    405. Kris Versteeg    -     LW, RW  $1,750,000  $1,750,000
# printing Player Name
# Testing
# Moving to next page
#                PLAYER TEAM     POS     CAP HIT      SALARY
# 0     451. Adam Lowry  WPG       C  $1,125,000  $1,250,000
# 1  452. Carter Hutton    -       G  $1,125,000  $1,000,000
# 2    453. Ryan Reaves  TOR      RW  $1,125,000  $1,125,000
# 3    454. Roman Polák    -      RD  $1,100,000  $1,100,000
# 4  455. Austin Watson  TBL  RW, LW  $1,100,000  $1,000,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM POS   CAP HIT    SALARY
# 0     501. Blake Hillman    -   D  $925,000  $925,000
# 1        502. Troy Terry  ANA  RW  $925,000  $925,000
# 2    503. Dylan Gambrell  TOR   C  $925,000  $925,000
# 3  504. Henrik Borgström  WSH   C  $925,000  $925,000
# 4     505. Eric Robinson  BUF  LW  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0         551. Neal Pionk  WPG      RD  $925,000  $925,000
# 1      552. Jakub Jeřábek    -      LD  $925,000  $925,000
# 2    553. Carl Grundström  LAK  LW, RW  $925,000  $925,000
# 3    554. Jonathan Dahlén    -  LW, RW  $925,000  $925,000
# 4  555. Alexei Bereglazov    -      LD  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                 PLAYER TEAM     POS   CAP HIT    SALARY
# 0       601. Kevin Roy    -   C, LW  $925,000  $925,000
# 1      602. Miles Wood  COL      LW  $925,000  $925,000
# 2  603. Steven Santini  LAK      RD  $925,000  $925,000
# 3      604. Nick Ellis    -       G  $925,000  $925,000
# 4     605. Tyler Motte  TBL  LW, RW  $925,000  $925,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS   CAP HIT    SALARY
# 0     651. Sam Reinhart  FLA      RW  $894,167  $832,500
# 1  652. Jason Dickinson  CHI   C, LW  $894,167  $832,500
# 2     653. Nick Ritchie    -      LW  $894,167  $832,500
# 3   654. Nikolaj Ehlers  WPG  RW, LW  $894,167  $832,500
# 4     655. Jared McCann  SEA   C, LW  $894,167  $832,500
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM     POS   CAP HIT    SALARY
# 0      701. Zach Senyshyn    -      RW  $863,333  $925,000
# 1       702. Jake DeBrusk  BOS  RW, LW  $863,333  $925,000
# 2  703. Evgeny Svechnikov    -  LW, RW  $863,333  $925,000
# 3      704. Thomas Chabot  OTT      LD  $863,333  $925,000
# 4      705. Mathew Barzal  NYI   C, RW  $863,333  $925,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM     POS   CAP HIT    SALARY
# 0    751. Klas Dahlbeck    -      LD  $850,000  $850,000
# 1     752. Shane Prince    -      LW  $850,000  $900,000
# 2     753. Zack MacEwen  OTT   RW, C  $847,500  $792,500
# 3      754. Ville Husso  DET       G  $847,500  $925,000
# 4  755. Jonah Gadjovich  FLA  LW, RW  $845,000        $0
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM    POS   CAP HIT    SALARY
# 0       801. Sean Kuraly  CBJ  C, LW  $808,750  $925,000
# 1     802. Dominik Masin    -     LD  $808,333  $925,000
# 2      803. Taylor Leier    -     LW  $806,558  $806,558
# 3  804. Linus Söderström    -      G  $803,333  $742,500
# 4   805. Adam Tambellini    -      C  $803,333  $925,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM     POS   CAP HIT    SALARY
# 0       851. Garrett Pilon  OTT       C  $775,833        $0
# 1            852. Sean Day  TBL      LD  $775,833        $0
# 2    853. Matthew Highmore  OTT  LW, RW  $775,833  $742,500
# 3     854. Andreas Englund  LAK      LD  $775,833  $792,500
# 4  855. Christoph Bertschy    -       C  $775,833  $892,500
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM        POS   CAP HIT    SALARY
# 0      901. Jack Kopacka    -         LW  $759,166        $0
# 1     902. Nicolas Petan  NYR  C, LW, RW  $758,333  $832,500
# 2       903. Maxim Mamin    -     LW, RW  $757,500  $732,500
# 3  904. Rasmus Andersson  CGY         RD  $755,833  $742,500
# 4   905. Christian Jaros    -         RD  $755,000  $730,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM     POS   CAP HIT    SALARY
# 0  951. Nicholas Caamano  DAL  LW, RW  $745,000        $0
# 1    952. Vitaly Abramov  OTT      LW  $745,000        $0
# 2   953. Kyle Capobianco  WPG      LD  $745,000  $742,500
# 3    954. Roland McKeown  NSH      RD  $745,000  $767,500
# 4   955. Laurent Dauphin    -       C  $745,000  $750,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS   CAP HIT    SALARY
# 0       1001. Filip Chlapik    -       C  $728,333  $742,500
# 1      1002. Brandon Gignac  MTL       C  $728,333        $0
# 2      1003. Nathan Bastian  NJD      RW  $728,333        $0
# 3        1004. Givani Smith  SJS  LW, RW  $728,333        $0
# 4  1005. Mitch Vande Sompel    -      LD  $728,333  $742,500
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM        POS   CAP HIT    SALARY
# 0      1051. Chase De Leo  ANA  C, LW, RW  $720,833  $765,000
# 1  1052. Jeremiah Addison    -         LW  $720,000  $720,000
# 2     1053. Simon Bourque    -         LD  $720,000  $720,000
# 3     1054. Maxime Lajoie  TOR         LD  $720,000        $0
# 4  1055. Gustav Bouramman    -         RD  $720,000  $730,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM POS   CAP HIT    SALARY
# 0    1101. Jack Rodewald    -  RW  $706,250  $690,000
# 1   1102. Spencer Watson    -  LW  $705,833  $730,000
# 2  1103. Lukas Bengtsson    -  RD  $705,000  $742,500
# 3     1104. Sean Maguire    -   G  $705,000  $742,500
# 4     1105. Kyle Schempp    -   C  $705,000  $742,500
# printing Player Name
# Testing
# Moving to next page
#                       PLAYER TEAM POS   CAP HIT    SALARY
# 0        1151. Jordin Tootoo    -  RW  $700,000  $700,000
# 1     1152. Conner Bleackley    -   C  $700,000  $725,000
# 2     1153. Stepan Falkovsky    -  LD  $698,333  $685,000
# 3           1154. Landon Bow    -   G  $697,500  $685,000
# 4  1155. Mackenzie Blackwood  SJS   G  $697,500  $742,500
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS   CAP HIT    SALARY
# 0  1201. Nicolas Aubé-Kubel  WSH      RW  $680,833  $650,000
# 1       1202. Conor Garland  VAN  RW, LW  $680,556  $730,000
# 2     1203. Joseph Blandisi    -       C  $680,000  $660,000
# 3       1204. Reece Willcox    -      RD  $680,000  $717,500
# 4       1205. Julien Nantel    -   C, LW  $680,000  $705,000
# printing Player Name
# Testing
# Moving to next page
#                      PLAYER TEAM     POS   CAP HIT    SALARY
# 0       1251. Ross Johnston  ANA      LW  $666,667  $710,000
# 1  1252. Frédérick Gaudreau  MIN   C, LW  $666,666  $650,000
# 2     1253. Tyler Lewington    -      RD  $665,000  $719,000
# 3        1254. Tim McGauley    -       C  $663,333  $705,000
# 4      1255. Tyler Bertuzzi  TOR  LW, RW  $661,667  $650,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM     POS   CAP HIT    SALARY
# 0     1301. Tyler Gaudet    -       C  $650,000  $650,000
# 1  1302. Garnet Hathaway  PHI  RW, LW  $650,000  $650,000
# 2     1303. Félix Girard    -       C  $650,000  $650,000
# 3     1304. Pontus Åberg    -  RW, LW  $650,000  $650,000
# 4       1305. Martin Frk    -      RW  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                  PLAYER TEAM    POS   CAP HIT    SALARY
# 0    1351. Jamie McBain    -     RD  $650,000  $650,000
# 1       1352. Mat Bodie    -     LD  $650,000  $650,000
# 2  1353. Cameron Gaunce    -     LD  $650,000  $650,000
# 3    1354. Marek Hrivík    -  C, LW  $650,000  $650,000
# 4    1355. Kevin Porter    -      C  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                   PLAYER TEAM     POS   CAP HIT    SALARY
# 0     1401. Byron Froese  VGK       C  $650,000  $650,000
# 1  1402. Jordan Oesterle  CGY   LD/RD  $650,000  $650,000
# 2  1403. Adam Clendening    -      RD  $650,000  $650,000
# 3   1404. Garrett Wilson    -  RW, LW  $650,000  $650,000
# 4     1405. Chase Balisy    -       C  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                    PLAYER TEAM    POS   CAP HIT    SALARY
# 0        1451. Logan Shaw    -  C, RW  $650,000  $650,000
# 1   1452. Michal Rozsíval    -     RD  $650,000  $650,000
# 2  1453. Fredrik Claesson    -     LD  $650,000  $650,000
# 3       1454. Justin Falk    -     LD  $650,000  $650,000
# 4      1455. Alex Stalock  ANA      G  $650,000  $650,000
# printing Player Name
# Testing
# Moving to next page
#                     PLAYER TEAM    POS   CAP HIT    SALARY
# 0        1501. Reid Petryk    -  C, RW  $622,500  $650,000
# 1  1502. Sergey Tolchinsky    -     LW  $616,667  $650,000
# 2   1503. Chris DiDomenico    -  C, RW  $612,500  $650,000
# 3         1504. Jeff Glass    -      G  $612,500  $650,000
# 4    1505. Matt Bartkowski    -     RD  $612,500  $650,000
# printing Player Name
# Testing
# Moving to next page
# Finished creating list of dfs to concatenate

# %%
salary_dfs = [player_sals_15, player_sals_16, player_sals_17]
final_dfs = join_dfs(nhl_dfs, salary_dfs)

# %%
write_csv(final_dfs)
# Out:
# 20152016
#           game_id  player_id  team_id  timeOnIce    CF    CA     C  \
# 0      2015020001    8467496        8       1304  47.0  54.0  -7.0
# 1      2015020001    8468504       10       1032  54.0  47.0   7.0
# 2      2015020001    8469521        8       1109  47.0  54.0  -7.0
# 3      2015020001    8469707       10        896  54.0  47.0   7.0
# 4      2015020001    8470039        8       1047  47.0  54.0  -7.0
# ...           ...        ...      ...        ...   ...   ...   ...
# 51208  2015030416    8476442       28        739  42.0  55.0 -13.0
# 51209  2015030416    8476874        5       1253  55.0  42.0  13.0
# 51210  2015030416    8476919       28        996  42.0  55.0 -13.0
# 51211  2015030416    8477839        5        924  55.0  42.0  13.0
# 51212  2015030416    8477922       28        765  42.0  55.0 -13.0
#
#        CF_Percent firstName     lastName primaryPosition     teamName  \
# 0        0.465347    Andrei       Markov               D    Canadiens
# 1        0.534653      Brad        Boyes              RW  Maple Leafs
# 2        0.465347     Tomas     Plekanec               C    Canadiens
# 3        0.534653        PA    Parenteau              RW  Maple Leafs
# 4        0.465347     Tomas  Fleischmann              LW    Canadiens
# ...           ...       ...          ...             ...          ...
# 51208    0.432990      Matt        Nieto              LW       Sharks
# 51209    0.567010      Olli       Maatta               D     Penguins
# 51210    0.432990     Chris      Tierney               C       Sharks
# 51211    0.567010     Conor       Sheary              LW     Penguins
# 51212    0.432990    Melker     Karlsson               C       Sharks
#
#       abbreviation     CAP HIT      SALARY
# 0              MTL  $5,750,000  $6,000,000
# 1              TOR    $700,000    $700,000
# 2              MTL  $5,000,000  $5,000,000
# 3              TOR         NaN         NaN
# 4              MTL    $750,000    $750,000
# ...            ...         ...         ...
# 51208          SJS    $759,167    $792,500
# 51209          PIT         NaN         NaN
# 51210          SJS    $711,667    $792,500
# 51211          PIT    $667,500    $667,500
# 51212          SJS  $1,650,000  $1,450,000
#
# [51213 rows x 15 columns]
# 20162017
#           game_id  player_id  team_id  timeOnIce    CF    CA    C  CF_Percent  \
# 0      2016020001    8467493        9        349  34.0  26.0  8.0    0.566667
# 1      2016020001    8467967        9        818  34.0  26.0  8.0    0.566667
# 2      2016020001    8470599       10        761  26.0  34.0 -8.0    0.433333
# 3      2016020001    8470602        9       1326  34.0  26.0  8.0    0.566667
# 4      2016020001    8470602        9       1326  34.0  26.0  8.0    0.566667
# ...           ...        ...      ...        ...   ...   ...  ...         ...
# 51058  2016030416    8477240        5        460  25.0  16.0  9.0    0.609756
# 51059  2016030416    8477404        5        960  25.0  16.0  9.0    0.609756
# 51060  2016030416    8477839        5        942  25.0  16.0  9.0    0.609756
# 51061  2016030416    8477919       18        465  16.0  25.0 -9.0    0.390244
# 51062  2016030416    8478042       18       1041  16.0  25.0 -9.0    0.390244
#
#        firstName   lastName primaryPosition     teamName abbreviation  \
# 0          Chris       Neil              RW     Senators          OTT
# 1          Chris      Kelly               C     Senators          OTT
# 2          Milan   Michalek              LW  Maple Leafs          TOR
# 3           Dion    Phaneuf               D     Senators          OTT
# 4           Dion    Phaneuf               D     Senators          OTT
# ...          ...        ...             ...          ...          ...
# 51058     Carter     Rowney              RW     Penguins          PIT
# 51059       Jake   Guentzel               C     Penguins          PIT
# 51060      Conor     Sheary              LW     Penguins          PIT
# 51061  Frederick   Gaudreau               C    Predators          NSH
# 51062     Viktor  Arvidsson              LW    Predators          NSH
#
#           CAP HIT      SALARY
# 0      $1,500,000  $1,500,000
# 1        $900,000    $900,000
# 2      $4,000,000  $4,000,000
# 3      $7,000,000  $7,500,000
# 4      $7,000,000  $7,500,000
# ...           ...         ...
# 51058    $612,500    $575,000
# 51059    $734,167    $667,500
# 51060    $667,500    $667,500
# 51061         NaN         NaN
# 51062    $631,667    $640,000
#
# [51063 rows x 15 columns]
# 20172018
#           game_id  player_id  team_id  timeOnIce    CF    CA    C  CF_Percent  \
# 0      2017020001    8466139       10        881  39.0  34.0  5.0    0.534247
# 1      2017020001    8468493       10       1373  39.0  34.0  5.0    0.534247
# 2      2017020001    8470611       10        913  39.0  34.0  5.0    0.534247
# 3      2017020001    8470828       52        758  34.0  39.0 -5.0    0.465753
# 4      2017020001    8470834       52       1339  34.0  39.0 -5.0    0.465753
# ...           ...        ...      ...        ...   ...   ...  ...         ...
# 52478  2017030415    8477930       54        620  43.0  43.0  0.0    0.500000
# 52479  2017030415    8477931       54        612  43.0  43.0  0.0    0.500000
# 52480  2017030415    8477944       15        933  43.0  43.0  0.0    0.500000
# 52481  2017030415    8477949       54        835  43.0  43.0  0.0    0.500000
# 52482  2017030415    8479482       15        959  43.0  43.0  0.0    0.500000
#
#             firstName   lastName primaryPosition        teamName abbreviation  \
# 0             Patrick    Marleau               C     Maple Leafs          TOR
# 1                 Ron    Hainsey               D     Maple Leafs          TOR
# 2                Eric       Fehr               C     Maple Leafs          TOR
# 3                Toby    Enstrom               D            Jets          WPG
# 4              Dustin  Byfuglien               D            Jets          WPG
# ...               ...        ...             ...             ...          ...
# 52478  Pierre-Edouard  Bellemare              LW  Golden Knights          VGK
# 52479           Tomas      Nosek              LW  Golden Knights          VGK
# 52480           Jakub      Vrana              LW        Capitals          WSH
# 52481            Alex       Tuch              RW  Golden Knights          VGK
# 52482          Michal     Kempny               D        Capitals          WSH
#
#           CAP HIT      SALARY
# 0      $6,250,000  $8,500,000
# 1      $3,000,000  $3,600,000
# 2      $2,000,000  $2,000,000
# 3             NaN         NaN
# 4      $7,600,000  $8,000,000
# ...           ...         ...
# 52478         NaN         NaN
# 52479    $612,500    $650,000
# 52480         NaN         NaN
# 52481    $925,000    $925,000
# 52482         NaN         NaN
#
# [52483 rows x 15 columns]
